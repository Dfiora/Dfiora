# %% [markdown]
# <a href="https://colab.research.google.com/github/Dfiora/Dfiora/blob/main/VAR_PSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np
#instalando pandas no meu ambiente google colab
# !pip install pandas

#importando a base do arquivo Excel a parti do meu pc
from google.colab import drive
drive.mount('/content/drive')
file_path = ('/content/2024-12-03 - P14 Séries Filtradas - Copiar.xlsx')
data = pd.read_excel('/content/2024-12-03 - P14 Séries Filtradas - Copiar.xlsx')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Exibir as primeiras linhas do dataframe
print(data.head())
# Out:
#         Date  PSV Term Charter Rates, Middle East, 500-750m²  \
# 0 2014-01-01                                         18000.0
# 1 2014-02-01                                         18000.0
# 2 2014-03-01                                         18000.0
# 3 2014-04-01                                         19000.0
# 4 2014-05-01                                         19500.0
#
#    PSV Term Charter Rates, SE Asia, 500-749m²  \
# 0                                     20000.0
# 1                                     19562.5
# 2                                     19250.0
# 3                                     19250.0
# 4                                     19250.0
#
#    PSV Term Charter Rates, US Gulf, 500-749m²  \
# 0                                     13900.0
# 1                                     13850.0
# 2                                     13850.0
# 3                                     13800.0
# 4                                     13800.0
#
# ...

# %%
#criando uma tabela interativa para melhor visualização da base
from google.colab import data_table # Import data_table instead of drive

data_table.enable_dataframe_formatter() # Call enable_dataframe_formatter from

base = pd.read_excel('/content/Base PSV.xlsx')
base
# Out:
#           Date  PSV Term Charter Rates, Middle East, 500-750m²  \
# 0   2014-01-01                                         18000.0
# 1   2014-02-01                                         18000.0
# 2   2014-03-01                                         18000.0
# 3   2014-04-01                                         19000.0
# 4   2014-05-01                                         19500.0
# ..         ...                                             ...
# 117 2023-10-01                                         16500.0
# 118 2023-11-01                                         17000.0
# 119 2023-12-01                                         17500.0
# 120 2024-01-01                                         17500.0
# 121 2024-02-01                                             NaN
#
#      PSV Term Charter Rates, SE Asia, 500-749m²  \
# 0                                       20000.0
# 1                                       19562.5
# 2                                       19250.0
# ...

# %%
data = data.drop(data.index[-1])
base
# Out:
#           Date  PSV Term Charter Rates, Middle East, 500-750m²  \
# 0   2014-01-01                                         18000.0
# 1   2014-02-01                                         18000.0
# 2   2014-03-01                                         18000.0
# 3   2014-04-01                                         19000.0
# 4   2014-05-01                                         19500.0
# ..         ...                                             ...
# 117 2023-10-01                                         16500.0
# 118 2023-11-01                                         17000.0
# 119 2023-12-01                                         17500.0
# 120 2024-01-01                                         17500.0
# 121 2024-02-01                                             NaN
#
#      PSV Term Charter Rates, SE Asia, 500-749m²  \
# 0                                       20000.0
# 1                                       19562.5
# 2                                       19250.0
# ...

# %%
data.tail()
# Out:
#           Date  PSV Term Charter Rates, Middle East, 500-750m²  \
# 114 2023-07-01                                         15000.0
# 115 2023-08-01                                         15000.0
# 116 2023-09-01                                         16000.0
# 117 2023-10-01                                         16500.0
# 118 2023-11-01                                         17000.0
#
#      PSV Term Charter Rates, SE Asia, 500-749m²  \
# 114                                     13300.0
# 115                                     13425.0
# 116                                     13920.0
# 117                                     14100.0
# 118                                     14500.0
#
#      PSV Term Charter Rates, US Gulf, 500-749m²  \
# 114                                     17000.0
# 115                                     17250.0
# 116                                     17333.0
# 117                                     17250.0
# ...
