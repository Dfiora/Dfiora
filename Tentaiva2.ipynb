# %% [markdown]
# <a href="https://colab.research.google.com/github/Dfiora/Dfiora/blob/main/Tentaiva2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from pandas.plotting import table

# %%
# !pip install pandas openpyxl

# %%
file_path = '2024-12-11 - P14 Duas Séries.xlsx'
data = pd.read_excel(file_path)

# %%
# Exibir as primeiras linhas do dataframe
print(data.head())

# Renomear colunas para facilitar o acesso
data.columns = ['Date', 'Brazil_Prices', 'International_Index']

# Converter a coluna 'Date' para o formato datetime
data['Date'] = pd.to_datetime(data['Date'])

# Definir 'Date' como índice
data.set_index('Date', inplace=True)
# Out:
#         Date  PSV Term Charter Rates, Brazil, 500-800m²  PSV Rate Index
# 0 1996-01-01                                 8094.97642        69.73707
# 1 1996-02-01                                 8726.53821        72.69132
# 2 1996-03-01                                 9358.10000        75.60865
# 3 1996-04-01                                 9291.17333        84.25671
# 4 1996-05-01                                 9224.24667        88.44680

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 338 entries, 1996-01-01 to 2024-02-01
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brazil_Prices        337 non-null    float64
#  1   International_Index  337 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Brazil_Prices  International_Index
# count     337.000000           337.000000
# mean    18587.323818           121.013838
# std      7175.987003            35.092836
# min      7549.520770            56.315080
# 25%     13000.000000            89.687450
# 50%     16512.935960           115.899430
# 75%     24600.000000           151.422090
# max     34000.000000           194.796360
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['Brazil_Prices'].plot(kind='hist', bins=20, title='Brazil_Prices')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['International_Index'].plot(kind='hist', bins=20, title='International_Index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
_df_3.plot(kind='scatter', x='Brazil_Prices', y='International_Index', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Get the describe table with 4 decimal places
describe_table = data.describe().applymap("{:.4f}".format)

# Create a figure and axes
fig, ax = plt.subplots(figsize=(12, 4))  # Adjust figsize as needed

# Hide axes
ax.axis('off')

# Create the table plot with increased font size and cell padding
tb = table(ax, describe_table, loc='center', fontsize=12,
           cellLoc='center', colWidths=[0.2]*len(describe_table.columns))

# Adjust cell padding to improve vertical alignment (experimental)
tb.auto_set_font_size(False)
tb.set_fontsize(12)
for cell in tb._cells:
    tb._cells[cell].set_height(0.15)  # Adjust cell height to fine-tune vertical spacing
    #tb._cells[cell]._text.set_verticalalignment('center') #This does not function here

# Save the plot as an image
plt.savefig('describe_table.png')
# Out:
# <ipython-input-24-c5ef900cd7fc>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   describe_table = data.describe().applymap("{:.4f}".format)
